# %% [markdown]
# <a href="https://colab.research.google.com/github/Diegoagdias/Sistema-Bancario-em-Python/blob/develop/C%C3%B3pia_de_Projetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔹 Construindo um Sistema Bancário em Python 🏦💰
#
# ## 📌 Descrição
# Você foi contratado para desenvolver um sistema bancário simples utilizando Python! O sistema deve permitir que o usuário realize depósitos, saques, visualize o extrato e encerre o programa. Todas as operações devem ser registradas e exibidas corretamente.
#
# ## 📌 Objetivo:
# Criar um sistema funcional que simule operações bancárias básicas.
#
# ## 📌 Regras do Sistema
# - 1️⃣ Depósito
#
# O usuário pode inserir um valor positivo e adicioná-lo ao saldo da conta.
# A operação deve ser registrada no extrato.
#
# - 2️⃣ Saque
#
# O usuário pode retirar um valor do saldo da conta.
# A operação deve ser registrada no extrato.
#
# - 3️⃣ Extrato
#
# Exibe todas as transações feitas (depósitos e saques).
# Exibe o saldo atual da conta.
#
# - 4️⃣ Sair
#
# O sistema deve permitir que o usuário encerre o programa digitando a opção correspondente.
#
# - 5️⃣ Validações (Bônus)
#
# O sistema não pode permitir saques se o saldo for insuficiente.
# O usuário não pode depositar valores negativos.
#
# ## 📌 Entrada
# O usuário interage com um menu numérico, escolhendo opções para realizar operações bancárias.
#
# ## 📌 Saída
# Mensagens informando o status das operações e um extrato detalhado das transações.
#
# ## 📌 Exemplo de Uso
# Exemplo de interação do usuário:
#
# ```
# ========== BANCO PYTHON ==========
# [1] Depósito
# [2] Saque
# [3] Extrato
# [4] Sair
# Escolha uma opção: 1
# Informe o valor do depósito: R$ 500.00
# Depósito de R$ 500.00 realizado com sucesso!
#
# ========== BANCO PYTHON ==========
# [1] Depósito
# [2] Saque
# [3] Extrato
# [4] Sair
# Escolha uma opção: 2
# Informe o valor do saque: R$ 200.00
# Saque de R$ 200.00 realizado com sucesso!
#
# ========== BANCO PYTHON ==========
# [1] Depósito
# [2] Saque
# [3] Extrato
# [4] Sair
# Escolha uma opção: 3
#
# ========== EXTRATO ==========
# Depósito: +R$ 500.00
# Saque: -R$ 200.00
#
# Saldo atual: R$ 300.00
# =============================
#
# ========== BANCO PYTHON ==========
# [1] Depósito
# [2] Saque
# [3] Extrato
# [4] Sair
# Escolha uma opção: 4
# Saindo do sistema...
# ```

# %%
valor = 0.0
valor_real = 0.0
extrato = []
def mostrar_menu():
    print("========== BANCO PYTHON ==========")
    print("[1] Depósito")
    print("[2] Saque")
    print("[3] Extrato")
    print("[4] Sair")
while True:
    mostrar_menu()
    try:
      escolha = int(input("Escolha uma opção: "))
      if escolha == 1: #Opção de Depósito
          valor = float(input("Informe o valor do depósito: R$ "))
          if valor > 0.0:
            valor_real = valor_real + valor
            extrato.append(f"Depósito: +R$ {valor:.2f}")
            print(f"Depósito de R$ {valor} realizado com sucesso!\n")
          else:
            print("Não pode depositar Valor Negativo\n")
      elif escolha == 2: # Opção de Saque
            valor = float(input("Informe o valor do saque: R$ "))
            if valor > 0:
                if valor_real >= valor:
                    valor_real -= valor
                    extrato.append(f"Saque: -R$ {valor:.2f}")
                    print(f"Saque de R$ {valor:.2f} realizado com sucesso!\n")
                else:
                    print("Não tem saldo suficiente para realizar o saque.\n")
            else:
                 print("Não pode Sacar Valor Negativo ou Zero\n")
      elif escolha == 3: # Opção Extrato
            print("\n========== EXTRATO ==========")

            if extrato: # Verifica se a lista não está vazia
                for transacao in extrato: # Para cada item na lista extrato...
                    print(transacao)     # ...imprima esse item.
            else:
                print("Não foram realizadas movimentações.")
            print(f"\nSaldo atual: R$ {valor_real:.2f}")
            print("=============================\n")
      elif escolha == 4:
          print("Saindo do sistema...")
          break
      else:
        print("Opção Inválida, tente novamente \n")
    except ValueError:
        print("Opção Inválida, tente novamente \n")

# %% [markdown]
# #🔹 Simulador de Caixa Eletrônico 💰
#
# Você precisa criar um simulador de caixa eletrônico, onde o usuário pode
#
# depositar, sacar e verificar o saldo.
#
# ## 📜 Regras:
#
# - O saldo inicial da conta é R$ 1000,00.
# - O usuário pode escolher uma operação:
# - 1️⃣ Depositar (O valor é adicionado ao saldo).
# - 2️⃣ Sacar (O valor é subtraído do saldo, se houver saldo suficiente).
# - 3️⃣ Sair do programa.
#
# ##🔹 Exemplo de Entrada e Saída:
#
# ```
# MENU:
# 1 - Depositar
# 2 - Sacar
# 3 - Sair
# Escolha uma opção: 1
# Digite o valor do depósito: 500
# Depósito realizado! Novo saldo: R$ 1500.00
#
# MENU:
# 1 - Depositar
# 2 - Sacar
# 3 - Sair
# Escolha uma opção: 2
# Digite o valor do saque: 2000
# Saldo insuficiente!
#
# MENU:
# 1 - Depositar
# 2 - Sacar
# 3 - Sair
# Escolha uma opção: 3
# Obrigado por usar nosso caixa eletrônico!
# ```

# %%
saldo = 1000
valorSaldo = 0.0
def menu():
  print("MENU:\n1 - Depositar\n2 - Sacar\n3 - Sair")
while True:
  menu()
  try:
    escolha = int(input("Escolha uma opção: "))
    if escolha == 1:
      valorSaldo = float(input("Digite o valor do depósito: "))
      if valorSaldo < 0:
        print("Valor Inválido")
      else:
        saldo = saldo + valorSaldo
      print(f"Depósito realizado! Novo saldo: R$ {saldo}\n")
    if escolha == 2:
      valorSaldo = float(input("Digite o valor do Saque: "))
      saldo = saldo - valorSaldo
      if saldo < 0:
        saldo = abs(saldo)
        saldo = valorSaldo - saldo
        print("Saldo insuficiente\n")
      else:
        print(f"Saque realizado! Novo saldo: R$ {saldo}")
    if escolha == 3:
      print("Obrigado por usar nosso caixa eletrônico!")
      break
    elif escolha <= 0 or escolha >3:
      print("Opção Inválida\n")
  except ValueError:
        print("Opção Inválida, tente novamente \n")

# %% [markdown]
# # 🔹 Jogo da Adivinhação 🎯
# Crie um jogo onde o usuário tenta adivinhar um número gerado aleatoriamente.
#
# ## 📜 Regras:
#
# - O programa gera um número aleatório entre 1 e 100.
# - O usuário tenta adivinhar e recebe dicas:
# - "Muito alto!" se o palpite for maior.
# - "Muito baixo!" se o palpite for menor.
# - O jogo continua até o usuário acertar.
#
# ##🔹 Exemplo de Entrada e Saída:
#
# ```
# Entrada: 50
# Saída: Muito alto!
#
# Entrada: 30
# Saída: Muito baixo!
#
# Entrada: 42
# Saída: Parabéns! Você acertou o número 42.
# ```

# %%
import random
for a in range(1):
  adivinha = random.randint(1, 100)
  a = 1
print("Tente adivinhar o número sorteado")
while True:
  print(adivinha)
  try:
    numero = int(input("Entrada "))
    if numero > adivinha:
      print("Saída: Muito alto!")
    elif numero < adivinha:
      print("Saída: Muito baixo!")
    else:
      print(f"Saída: Parabéns! Você acertou o número {adivinha}.")
      break
  except ValueError:
    print("Opção Inválida, tente novamente \n")

# %% [markdown]
# #🔹 Simulador de Estoque Inteligente 📦
# Crie um sistema onde o usuário pode adicionar, remover e verificar itens em um estoque.
#
# ## 📜 Regras:
#
# - O usuário pode adicionar um item ao estoque.
# - O usuário pode remover um item, se ele existir no estoque.
# - O programa exibe a quantidade total de itens.
#
# ##🔹 Exemplo de Entrada e Saída:
#
# ```
# MENU:
# 1 - Adicionar item
# 2 - Remover item
# 3 - Ver estoque
# 4 - Sair
#
# Entrada: 1
# Nome do item: Celular
# Quantidade: 3
#
# Entrada: 1
# Nome do item: Notebook
# Quantidade: 2
#
# Entrada: 3
# Saída: Estoque: {'Celular': 3, 'Notebook': 2}
#
# Entrada: 2
# Nome do item: Celular
# Quantidade: 1
#
# Entrada: 3
# Saída: Estoque: {'Celular': 2, 'Notebook': 2}
# ```

# %%
print("Estoque Inteligente")
def menu_estoque():
  print("MENU:")
  print("1 - Adicionar item")
  print("2 - Remover item")
  print("3 - Ver estoque")
  print("4 - Sair\n")
def item():
  item = input("Nome do item: ")
  qtde = int(input("Quantidade: "))
  print("\n")
while True:
  menu_estoque()
  try:
    escolha = int(input("Entrada: "))
    if escolha == 1:
      item()
    elif escolha == 2:
      item()
    elif escolha == 3:
      item()
    elif escolha == 4:
      break
  except ValueError:
    print("Opção Inválida, tente novamente \n")

# %% [markdown]
# # 🔹 Verificador de Números de Chamados Atendidos 📞🔍
#
# ## 📌 Descrição
#
# Imagine que você trabalha no suporte técnico de uma empresa e precisa criar um sistema de controle de chamados.
#
# Esse sistema mantém um registro dos chamados atendidos dentro de uma lista limitada de números de chamados.
#
# ## O usuário pode:
# - ✅ Registrar novos chamados atendidos.
# - ✅ Verificar se um chamado já foi atendido.
# - ✅ Exibir todos os chamados atendidos.
#
# ## 📜 Regras
# - 1️⃣ O sistema suporta apenas um número máximo de chamados atendidos (exemplo: 50).
# - 2️⃣ O usuário pode adicionar um número de chamado ao registro, desde que ainda haja espaço na lista.
# - 3️⃣ O usuário pode pesquisar um número para verificar se ele já foi atendido.
# - 4️⃣ Se a lista estiver cheia, o sistema impede novas adições.
# - 5️⃣ O usuário pode visualizar a lista de chamados atendidos.
# - 6️⃣ Se o usuário tentar adicionar um chamado já registrado, o sistema exibe um aviso.
#
# ##🔹 Exemplo de Entrada e Saída
#
# ```
# MENU:
# 1 - Registrar chamado atendido
# 2 - Verificar se um chamado foi atendido
# 3 - Listar todos os chamados atendidos
# 4 - Sair
#
# Entrada: 1
# Digite o número do chamado: 1023
# Saída: Chamado 1023 registrado com sucesso!
#
# Entrada: 1
# Digite o número do chamado: 1023
# Saída: Erro! O chamado 1023 já foi atendido.
#
# Entrada: 2
# Digite o número do chamado para verificar: 1023
# Saída: Chamado 1023 foi atendido.
#
# Entrada: 3
# Saída: Chamados atendidos: [1023]
#
# Entrada: 4
# Saída: Saindo do sistema...
# ```

# %%
#🔹 Verificador de Números de Chamados Atendidos 📞🔍
print("Verificador de Números de Chamados Atendidos")
chamado = []
registro = 0
registro_chamado = 0
def menu_chamado():
  print("MENU:")
  print("1 - Registrar chamado atendido")
  print("2 - Verificar se um chamado foi atendido")
  print("3 - Listar todos os chamados atendidos")
  print("4 - Sair\n")
while True:
  menu_chamado()
  try:
    registro = int(input("Entrada: "))
    if registro == 1:
      if chamado:
        registro_chamado = int(print("Digite o número do chamado: "))
        chamado.append(f"Saída: Chamado {registro_chamado} registrado com sucesso! ")
      else:
        print(f"Saída: Erro! O chamado {registro_chamado} já foi atendido.")
    elif registro == 2:
      break
    elif registro == 3:
      print(f"Chamados atendidos: [{chamados}]")
      break
    elif registro == 4:
      print("Saindo do Sistema...")
      break
    else:
      print("Opção Inválida, digite o menu correto\n")
  except ValueError:
    print("Opção Inválida, tente novamente \n")
# Out:
# Verificador de Números de Chamados Atendidos
# MENU:
# 1 - Registrar chamado atendido
# 2 - Verificar se um chamado foi atendido
# 3 - Listar todos os chamados atendidos
# 4 - Sair
#
# Entrada: 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7e4dfdd6bee1> in <cell line: 0>()
#      15     registro = int(input("Entrada: "))
#      16     if registro == 1:
# ---> 17       if chamado in registro_chamado:
#      18         registro_chamado = int(print("Digite o número do chamado: "))
#      19         chamado.append(f"Saída: Chamado {registro_chamado} registrado com sucesso! ")
#
# TypeError: argument of type 'int' is not iterable

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.to_csv("/content/sample_data/california_housing_test.csv")
